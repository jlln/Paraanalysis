# %%
import pandas

directory='./MiSeqSFPQc.csv_MiSeqNONOc.csv_HuRc_conversioncTranscripts/'

hurc=pandas.read_csv(directory+'HuRc_conversioncfeature_cluster_table.csv')
SFPQ=pandas.read_csv(directory+'MiSeqSFPQc.csvfeature_cluster_table.csv')
NONO=pandas.read_csv(directory+'MiSeqNONOc.csvfeature_cluster_table.csv')

datasets=[hurc,SFPQ,NONO]
for x in datasets:
    del x['Unnamed: 0']
    x.iloc[:,1]=x.iloc[:,1].div(x.iloc[:,1].sum(axis=1), axis=0)*100
    sample=[x.columns[1]]*len(x.index)
    x['Sample']=sample
    x.columns=[u'Feature_Type', u'Percentage of Clusters in this Feature Type', u'Sample']
data=pandas.concat(datasets)
data=data.fillna(0)

# %%
data
# Out:
#                                   Feature_Type  \
# 0                   Exon from 3'-UTR to 3'-UTR
# 1                   Exon from 5'-UTR to 5'-UTR
# 2                              Exon in a ncRNA
# 3   Intron from Coding_Region to Coding_Region
# 4                            Translation_Start
# 5            Exon from 5'-UTR to Coding_Region
# 6     Exon from Coding_Region to Coding_Region
# 7                   Exon from 5'-UTR to 3'-UTR
# 8                 Intron from 3'-UTR to 3'-UTR
# 9                            Intron in a ncRNA
# 10                                      3'-UTR
# 11                Intron from 5'-UTR to 5'-UTR
# 12                                      5'-UTR
# 13           Exon from Coding_Region to 3'-UTR
# 0             Splice Junction 5'-UTR to 3'-UTR
# 1                   Exon from 3'-UTR to 3'-UTR
# 2                              Exon in a ncRNA
# 3   Intron from Coding_Region to Coding_Region
# 4            Exon from 5'-UTR to Coding_Region
# 5                   Exon from 5'-UTR to 3'-UTR
# 6                 Intron from 3'-UTR to 3'-UTR
# 7                            Intron in a ncRNA
# 8                                       3'-UTR
# 9                 Intron from 5'-UTR to 5'-UTR
# 10                                      5'-UTR
# 11           Exon from Coding_Region to 3'-UTR
# 0            Exon from 5'-UTR to Coding_Region
# 1                              Exon in a ncRNA
# 2   Intron from Coding_Region to Coding_Region
# 3                   Exon from 5'-UTR to 5'-UTR
# 4                   Exon from 5'-UTR to 3'-UTR
# 5                 Intron from 3'-UTR to 3'-UTR
# 6                            Intron in a ncRNA
# 7                                       3'-UTR
# 8                 Intron from 5'-UTR to 5'-UTR
# 9                                       5'-UTR
#
#     Percentage of Clusters in this Feature Type                  Sample
# 0                                      0.445434  HuRc_conversionc Count
# 1                                      1.559020  HuRc_conversionc Count
# 2                                      7.795100  HuRc_conversionc Count
# 3                                     12.026726  HuRc_conversionc Count
# 4                                      0.222717  HuRc_conversionc Count
# 5                                     14.476615  HuRc_conversionc Count
# 6                                      0.222717  HuRc_conversionc Count
# 7                                      2.449889  HuRc_conversionc Count
# 8                                      2.227171  HuRc_conversionc Count
# 9                                      6.013363  HuRc_conversionc Count
# 10                                    19.153675  HuRc_conversionc Count
# 11                                     1.336303  HuRc_conversionc Count
# 12                                    19.153675  HuRc_conversionc Count
# 13                                    12.917595  HuRc_conversionc Count
# 0                                      0.123305    MiSeqSFPQc.csv Count
# 1                                      0.123305    MiSeqSFPQc.csv Count
# 2                                     20.838471    MiSeqSFPQc.csv Count
# 3                                     19.482121    MiSeqSFPQc.csv Count
# 4                                      0.369914    MiSeqSFPQc.csv Count
# 5                                      2.959309    MiSeqSFPQc.csv Count
# 6                                      8.261406    MiSeqSFPQc.csv Count
# 7                                     11.220715    MiSeqSFPQc.csv Count
# 8                                     12.083847    MiSeqSFPQc.csv Count
# 9                                     12.207152    MiSeqSFPQc.csv Count
# 10                                    12.083847    MiSeqSFPQc.csv Count
# 11                                     0.246609    MiSeqSFPQc.csv Count
# 0                                      0.272480    MiSeqNONOc.csv Count
# 1                                     20.435967    MiSeqNONOc.csv Count
# 2                                     16.621253    MiSeqNONOc.csv Count
# 3                                      0.136240    MiSeqNONOc.csv Count
# 4                                      4.904632    MiSeqNONOc.csv Count
# 5                                      8.310627    MiSeqNONOc.csv Count
# 6                                     13.351499    MiSeqNONOc.csv Count
# 7                                     13.079019    MiSeqNONOc.csv Count
# 8                                     11.444142    MiSeqNONOc.csv Count
# 9                                     11.444142    MiSeqNONOc.csv Count
#
# [36 rows x 3 columns]

# %%
Translation_Status=[]
Feature_Type=[]
def feature_classifier(row):
    feature=row['Feature_Type']
    if "ncRNA" in feature:
        Translation_Status.append("ncRNA")
    else:
        Translation_Status.append("mRNA")
    if "UTR" in feature:
        Feature_Type.append("UTR")
    elif "Exon" in feature:
        Feature_Type.append("Exon")
    elif "Intron" in feature:
        Feature_Type.append("Intron")
    elif "Splice" in feature:
        Feature_Type.append("Splice Junction")
    elif "Start" in feature:
        Feature_Type.append("Translation Start")
    
data.apply(feature_classifier,axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# dtype: object

# %%
data['Transcript_Type']=Translation_Status
data['Feature_Category']=Feature_Type

# %%
data
# Out:
#                                   Feature_Type  \
# 0                   Exon from 3'-UTR to 3'-UTR
# 1                   Exon from 5'-UTR to 5'-UTR
# 2                              Exon in a ncRNA
# 3   Intron from Coding_Region to Coding_Region
# 4                            Translation_Start
# 5            Exon from 5'-UTR to Coding_Region
# 6     Exon from Coding_Region to Coding_Region
# 7                   Exon from 5'-UTR to 3'-UTR
# 8                 Intron from 3'-UTR to 3'-UTR
# 9                            Intron in a ncRNA
# 10                                      3'-UTR
# 11                Intron from 5'-UTR to 5'-UTR
# 12                                      5'-UTR
# 13           Exon from Coding_Region to 3'-UTR
# 0             Splice Junction 5'-UTR to 3'-UTR
# 1                   Exon from 3'-UTR to 3'-UTR
# 2                              Exon in a ncRNA
# 3   Intron from Coding_Region to Coding_Region
# 4            Exon from 5'-UTR to Coding_Region
# 5                   Exon from 5'-UTR to 3'-UTR
# 6                 Intron from 3'-UTR to 3'-UTR
# 7                            Intron in a ncRNA
# 8                                       3'-UTR
# 9                 Intron from 5'-UTR to 5'-UTR
# 10                                      5'-UTR
# 11           Exon from Coding_Region to 3'-UTR
# 0            Exon from 5'-UTR to Coding_Region
# 1                              Exon in a ncRNA
# 2   Intron from Coding_Region to Coding_Region
# 3                   Exon from 5'-UTR to 5'-UTR
# 4                   Exon from 5'-UTR to 3'-UTR
# 5                 Intron from 3'-UTR to 3'-UTR
# 6                            Intron in a ncRNA
# 7                                       3'-UTR
# 8                 Intron from 5'-UTR to 5'-UTR
# 9                                       5'-UTR
#
#     Percentage of Clusters in this Feature Type                  Sample  \
# 0                                      0.445434  HuRc_conversionc Count
# 1                                      1.559020  HuRc_conversionc Count
# 2                                      7.795100  HuRc_conversionc Count
# 3                                     12.026726  HuRc_conversionc Count
# 4                                      0.222717  HuRc_conversionc Count
# 5                                     14.476615  HuRc_conversionc Count
# 6                                      0.222717  HuRc_conversionc Count
# 7                                      2.449889  HuRc_conversionc Count
# 8                                      2.227171  HuRc_conversionc Count
# 9                                      6.013363  HuRc_conversionc Count
# 10                                    19.153675  HuRc_conversionc Count
# 11                                     1.336303  HuRc_conversionc Count
# 12                                    19.153675  HuRc_conversionc Count
# 13                                    12.917595  HuRc_conversionc Count
# 0                                      0.123305    MiSeqSFPQc.csv Count
# 1                                      0.123305    MiSeqSFPQc.csv Count
# 2                                     20.838471    MiSeqSFPQc.csv Count
# 3                                     19.482121    MiSeqSFPQc.csv Count
# 4                                      0.369914    MiSeqSFPQc.csv Count
# 5                                      2.959309    MiSeqSFPQc.csv Count
# 6                                      8.261406    MiSeqSFPQc.csv Count
# 7                                     11.220715    MiSeqSFPQc.csv Count
# 8                                     12.083847    MiSeqSFPQc.csv Count
# 9                                     12.207152    MiSeqSFPQc.csv Count
# 10                                    12.083847    MiSeqSFPQc.csv Count
# 11                                     0.246609    MiSeqSFPQc.csv Count
# 0                                      0.272480    MiSeqNONOc.csv Count
# 1                                     20.435967    MiSeqNONOc.csv Count
# 2                                     16.621253    MiSeqNONOc.csv Count
# 3                                      0.136240    MiSeqNONOc.csv Count
# 4                                      4.904632    MiSeqNONOc.csv Count
# 5                                      8.310627    MiSeqNONOc.csv Count
# 6                                     13.351499    MiSeqNONOc.csv Count
# 7                                     13.079019    MiSeqNONOc.csv Count
# 8                                     11.444142    MiSeqNONOc.csv Count
# 9                                     11.444142    MiSeqNONOc.csv Count
#
#    Transcript_Type   Feature_Category
# 0             mRNA                UTR
# 1             mRNA                UTR
# 2            ncRNA               Exon
# 3             mRNA             Intron
# 4             mRNA  Translation Start
# 5             mRNA                UTR
# 6             mRNA               Exon
# 7             mRNA                UTR
# 8             mRNA                UTR
# 9            ncRNA             Intron
# 10            mRNA                UTR
# 11            mRNA                UTR
# 12            mRNA                UTR
# 13            mRNA                UTR
# 0             mRNA                UTR
# 1             mRNA                UTR
# 2            ncRNA               Exon
# 3             mRNA             Intron
# 4             mRNA                UTR
# 5             mRNA                UTR
# 6             mRNA                UTR
# 7            ncRNA             Intron
# 8             mRNA                UTR
# 9             mRNA                UTR
# 10            mRNA                UTR
# 11            mRNA                UTR
# 0             mRNA                UTR
# 1            ncRNA               Exon
# 2             mRNA             Intron
# 3             mRNA                UTR
# 4             mRNA                UTR
# 5             mRNA                UTR
# 6            ncRNA             Intron
# 7             mRNA                UTR
# 8             mRNA                UTR
# 9             mRNA                UTR
#
# [36 rows x 5 columns]

# %%
data=data.sort(['Feature_Category'])

# %%
#Save a csv to plot in R ggplot2
data.to_csv(directory+"featurebindingproportions.csv")

# %%
g=data.groupby(['Sample','Transcript_Type','Feature_Category'])

# %%
g.sum().reset_index().to_csv('featurebindingproportiontable.csv')

# %%
g=g.sum().reset_index()

# %%
g
# Out:
#                     Sample Transcript_Type   Feature_Category  \
# 0   HuRc_conversionc Count            mRNA               Exon
# 1   HuRc_conversionc Count            mRNA             Intron
# 2   HuRc_conversionc Count            mRNA  Translation Start
# 3   HuRc_conversionc Count            mRNA                UTR
# 4   HuRc_conversionc Count           ncRNA               Exon
# 5   HuRc_conversionc Count           ncRNA             Intron
# 6     MiSeqNONOc.csv Count            mRNA             Intron
# 7     MiSeqNONOc.csv Count            mRNA                UTR
# 8     MiSeqNONOc.csv Count           ncRNA               Exon
# 9     MiSeqNONOc.csv Count           ncRNA             Intron
# 10    MiSeqSFPQc.csv Count            mRNA             Intron
# 11    MiSeqSFPQc.csv Count            mRNA                UTR
# 12    MiSeqSFPQc.csv Count           ncRNA               Exon
# 13    MiSeqSFPQc.csv Count           ncRNA             Intron
#
#     Percentage of Clusters in this Feature Type
# 0                                      0.222717
# 1                                     12.026726
# 2                                      0.222717
# 3                                     73.719376
# 4                                      7.795100
# 5                                      6.013363
# 6                                     16.621253
# 7                                     49.591281
# 8                                     20.435967
# 9                                     13.351499
# 10                                    19.482121
# 11                                    48.458693
# 12                                    20.838471
# 13                                    11.220715
#
# [14 rows x 4 columns]

# %% [markdown]
# #### Now to make a more accurate prediction of the proportion of translated/untranslated exons that are bound.

# %%
directory="MiSeqSFPQc.csv_MiSeqNONOc.csvTranscripts/"   
datasets=[]

filename_index=pandas.read_csv(directory+"cluster_and_transcript_annotation_file_index.csv")
translation_status=pandas.read_csv(directory+"_Translation_Status_Totals.csv")
for x in translation_status.columns[1:]:
	datasets.append(x)

# %%
def describe_features_within_cluster(cluster):

	cluster_start=cluster['ClusterStart']
	cluster_end=cluster['ClusterEnd']
	matched_features_list=[]
	for transcript in eval(cluster['transcripts']):
		annotation=pandas.read_csv(directory+transcript+'annotations.csv')
		
		matched_features=annotation[annotation['feature_start']<cluster_end]
		matched_features=matched_features[matched_features['feature_end']>cluster_start]
		matched_features['transcript']=transcript
		matched_features_list.append(matched_features)
        
        
        
	if len(matched_features_list)>0:
		cluster_features=pandas.concat(matched_features_list)
		del cluster_features['Unnamed: 0']
		cluster_features.rename(columns=lambda x: x.replace('feature_classification', 'feature_subtype'), inplace=True)
		groups=cluster_features.groupby(['feature_start','feature_end','feature_subtype'])
		groups=groups.size().reset_index()      #This eliminates replicate features
		groups.columns=["Feature Start","Feature End","Feature Subtype", "Feature Occurance Count within Cluster"]
		
		list_of_features.extend(groups['Feature Subtype'])
