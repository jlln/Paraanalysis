# %% [markdown]
# # Mapping Clusters to Specific Features

# %% [markdown]
# #### Because of alternative splicing, some features will be overrepresented. To avoid this, features are listed by their type, chromosome, and start & end coordinates. Only unique features from this list are included in subsequent steps. If a cluster intersects a feature whatsoever, that feature will be counted. This means that a cluster spanning a junction will represent multiple features, including the junction itself.
# This script creates a csv file in the working directory named "feature_cluster_table.csv"

# %%
import pandas
import sys
import numpy as np

pandas.set_option('line_width', 160)

# directory=sys.argv[1] Note again that this has been commented out to allow the script to run in the notebook for this demonstration.
directory="MiSeqSFPQc.csv_MiSeqNONOc.csvTranscripts/"   
datasets=[]

filename_index=pandas.read_csv(directory+"cluster_and_transcript_annotation_file_index.csv")
translation_status=pandas.read_csv(directory+"_Translation_Status_Totals.csv")
for x in translation_status.columns[1:]:
	datasets.append(x)



list_of_features=[]
def describe_features_within_cluster(cluster):

	cluster_start=cluster['ClusterStart']
	cluster_end=cluster['ClusterEnd']
	matched_features_list=[]
	for transcript in eval(cluster['transcripts']):
		annotation=pandas.read_csv(directory+transcript+'annotations.csv')
		
		matched_features=annotation[annotation['feature_start']<cluster_end]
		matched_features=matched_features[matched_features['feature_end']>cluster_start]
		matched_features['transcript']=transcript
		matched_features_list.append(matched_features)
	if len(matched_features_list)>0:
		cluster_features=pandas.concat(matched_features_list)
		del cluster_features['Unnamed: 0']
		cluster_features.rename(columns=lambda x: x.replace('feature_classification', 'feature_subtype'), inplace=True)
		groups=cluster_features.groupby(['feature_start','feature_end','feature_subtype'])
		groups=groups.size().reset_index()      #This eliminates replicate features
		groups.columns=["Feature Start","Feature End","Feature Subtype", "Feature Occurance Count within Cluster"]
		
		list_of_features.extend(groups['Feature Subtype'])





feature_dfs=[]
for d in datasets:
	list_of_features=[]
	matched_reads=pandas.read_csv(directory+d+"matchedreads.csv")
	matched_reads.apply(describe_features_within_cluster,axis=1)
	feature_subtypes=set(list_of_features)
	print feature_subtypes
	df_type_list=[]
	df_type_count=[]
	for f in feature_subtypes:
		df_type_list.append(f)
		df_type_count.append(list_of_features.count(f))
	df_d={"Feature_Type":df_type_list,"%s Count"%d:df_type_count}
	totals=pandas.DataFrame(df_d)
	totals.to_csv(directory+d+"feature_cluster_table.csv")
	feature_dfs.append(totals)


t=pandas.merge(left=feature_dfs[0],right=feature_dfs[1],on="Feature_Type",how="outer")
t=t.fillna(0)
tt=t.T
tt.columns=tt.iloc[0,]
df = tt.drop(tt.index[0])
df=df.div(df.sum(axis=1), axis=0)*100
df
# Out:
# set(["Splice Junction Splice Junction Exon from 5'-UTR to 5'-UTR to Intron from 5'-UTR to 5'-UTR to Splice Junction Intron from 5'-UTR to 5'-UTR to Exon from 5'-UTR to Coding_Region", "Splice Junction 5'-UTR to 3'-UTR", "Exon from 5'-UTR to Coding_Region", "Splice Junction Splice Junction Exon from 3'-UTR to 3'-UTR to Intron from 3'-UTR to 3'-UTR to Splice Junction Intron from 3'-UTR to 3'-UTR to Exon from 3'-UTR to 3'-UTR", 'Intron from Coding_Region to Coding_Region', "Exon from Coding_Region to 3'-UTR", "Splice Junction Splice Junction Exon from Coding_Region to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to 3'-UTR", "Splice Junction Splice Junction Exon from Coding_Region to 3'-UTR to Intron from 3'-UTR to 3'-UTR to Splice Junction Intron from 3'-UTR to 3'-UTR to Exon from 3'-UTR to 3'-UTR", 'Exon in a ncRNA', 'Splice Junction Splice Junction Exon in a ncRNA to Intron in a ncRNA to Splice Junction Intron in a ncRNA to Exon in a ncRNA', "Splice Junction Splice Junction Exon from 5'-UTR to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to Coding_Region", "Exon from 5'-UTR to 3'-UTR", "Intron from 3'-UTR to 3'-UTR", 'Intron in a ncRNA', "3'-UTR", "Intron from 5'-UTR to 5'-UTR", "5'-UTR", "Exon from 3'-UTR to 3'-UTR", 'Splice Junction Splice Junction Exon from Coding_Region to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to Coding_Region', "Splice Junction Splice Junction Exon from 5'-UTR to 5'-UTR to Intron from 5'-UTR to 5'-UTR to Splice Junction Intron from 5'-UTR to 5'-UTR to Exon from 5'-UTR to 5'-UTR"])
# set(["Splice Junction Splice Junction Exon from 5'-UTR to 5'-UTR to Intron from 5'-UTR to 5'-UTR to Splice Junction Intron from 5'-UTR to 5'-UTR to Exon from 5'-UTR to Coding_Region", "Exon from 5'-UTR to 5'-UTR", "Splice Junction Splice Junction Exon from 5'-UTR to 5'-UTR to Intron from 5'-UTR to 5'-UTR to Splice Junction Intron from 5'-UTR to 5'-UTR to Exon from 5'-UTR to 5'-UTR", "Exon from 5'-UTR to Coding_Region", 'Intron from Coding_Region to Coding_Region', "Splice Junction Splice Junction Exon from Coding_Region to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to 3'-UTR", "Splice Junction Splice Junction Exon from Coding_Region to 3'-UTR to Intron from 3'-UTR to 3'-UTR to Splice Junction Intron from 3'-UTR to 3'-UTR to Exon from 3'-UTR to 3'-UTR", 'Exon in a ncRNA', "Splice Junction Splice Junction Exon from 5'-UTR to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to 3'-UTR", 'Splice Junction Splice Junction Exon in a ncRNA to Intron in a ncRNA to Splice Junction Intron in a ncRNA to Exon in a ncRNA', "Splice Junction Splice Junction Exon from 5'-UTR to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to Coding_Region", "Exon from 5'-UTR to 3'-UTR", "Intron from 3'-UTR to 3'-UTR", 'Intron in a ncRNA', "3'-UTR", "Intron from 5'-UTR to 5'-UTR", "5'-UTR", 'Splice Junction Splice Junction Exon from Coding_Region to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to Coding_Region', "Splice Junction Splice Junction Exon from 3'-UTR to 3'-UTR to Intron from 3'-UTR to 3'-UTR to Splice Junction Intron from 3'-UTR to 3'-UTR to Exon from 3'-UTR to 3'-UTR"])
# Feature_Type         Splice Junction Splice Junction Exon from 5'-UTR to 5'-UTR to Intron from 5'-UTR to 5'-UTR to Splice Junction Intron from 5'-UTR to 5'-UTR to Exon from 5'-UTR to Coding_Region  \
# MiSeqSFPQc.csv Count                                           2.477701
# MiSeqNONOc.csv Count                                            1.62037
#
# Feature_Type         Splice Junction 5'-UTR to 3'-UTR Exon from 5'-UTR to Coding_Region  \
# MiSeqSFPQc.csv Count                       0.09910803                         0.2973241
# MiSeqNONOc.csv Count                                0                         0.2314815
#
# Feature_Type         Splice Junction Splice Junction Exon from 3'-UTR to 3'-UTR to Intron from 3'-UTR to 3'-UTR to Splice Junction Intron from 3'-UTR to 3'-UTR to Exon from 3'-UTR to 3'-UTR  \
# MiSeqSFPQc.csv Count                                           1.288404
# MiSeqNONOc.csv Count                                          0.6944444
#
# Feature_Type         Intron from Coding_Region to Coding_Region Exon from Coding_Region to 3'-UTR  \
# MiSeqSFPQc.csv Count                                   15.65907                         0.1982161
# MiSeqNONOc.csv Count                                   14.12037                                 0
#
# Feature_Type         Splice Junction Splice Junction Exon from Coding_Region to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to 3'-UTR  \
# MiSeqSFPQc.csv Count                                           1.387512
# MiSeqNONOc.csv Count                                           1.388889
#
# Feature_Type         Splice Junction Splice Junction Exon from Coding_Region to 3'-UTR to Intron from 3'-UTR to 3'-UTR to Splice Junction Intron from 3'-UTR to 3'-UTR to Exon from 3'-UTR to 3'-UTR  \
# MiSeqSFPQc.csv Count                                          0.8919722
# MiSeqNONOc.csv Count                                           1.157407
#
# Feature_Type         Exon in a ncRNA  \
# MiSeqSFPQc.csv Count        16.74926
# MiSeqNONOc.csv Count        17.36111
#
# Feature_Type         Splice Junction Splice Junction Exon in a ncRNA to Intron in a ncRNA to Splice Junction Intron in a ncRNA to Exon in a ncRNA  \
# MiSeqSFPQc.csv Count                                          0.6937562
# MiSeqNONOc.csv Count                                          0.3472222
#
# Feature_Type         Splice Junction Splice Junction Exon from 5'-UTR to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to Coding_Region  \
# MiSeqSFPQc.csv Count                                           4.757185
# MiSeqNONOc.csv Count                                           3.587963
#
# Feature_Type         Exon from 5'-UTR to 3'-UTR Intron from 3'-UTR to 3'-UTR Intron in a ncRNA    3'-UTR Intron from 5'-UTR to 5'-UTR    5'-UTR  \
# MiSeqSFPQc.csv Count                   2.378593                     6.640238          9.018831  9.712587                     9.811695  9.712587
# MiSeqNONOc.csv Count                   4.166667                     7.060185          11.34259  11.11111                     9.722222  9.722222
#
# Feature_Type         Exon from 3'-UTR to 3'-UTR  \
# MiSeqSFPQc.csv Count                 0.09910803
# MiSeqNONOc.csv Count                          0
#
# Feature_Type         Splice Junction Splice Junction Exon from Coding_Region to Coding_Region to Intron from Coding_Region to Coding_Region to Splice Junction Intron from Coding_Region to Coding_Region to Exon from Coding_Region to Coding_Region  \
# MiSeqSFPQc.csv Count                                           5.153617
# MiSeqNONOc.csv Count                                           4.282407
#
# Feature_Type         Splice Junction Splice Junction Exon from 5'-UTR to 5'-UTR to Intron from 5'-UTR to 5'-UTR to Splice Junction Intron from 5'-UTR to 5'-UTR to Exon from 5'-UTR to 5'-UTR  \
# MiSeqSFPQc.csv Count                                           2.973241
# MiSeqNONOc.csv Count                                           1.851852
#
# Feature_Type
# MiSeqSFPQc.csv Count ...
# MiSeqNONOc.csv Count ...
#
# [2 rows x 22 columns]

# %%
df2=df
try:
    df2['mRNA_CDS_exons']=df["Exon from Coding_Region to Coding_Region"]
except:
    pass

df2['mRNA_UTR_exons']=df["Exon from 5'-UTR to Coding_Region"]+df["Exon from 3'-UTR to 3'-UTR"]+df["Exon from 5'-UTR to 5'-UTR"]+df["Exon from 5'-UTR to 3'-UTR"]+df["Exon from Coding_Region to 3'-UTR"]
df2['ncRNA_exons']=df["Exon in a ncRNA"]
df2["3'-UTR"]=df["3'-UTR"]
df2["5'-UTR"]=df["5'-UTR"]
df2["mRNA_Introns"]=df["Intron from Coding_Region to Coding_Region"]+df["Intron from 3'-UTR to 3'-UTR"]+df["Intron from 5'-UTR to 5'-UTR"]
df2["ncRNA_Introns"]=df["Intron in a ncRNA"]
cols=[x for x in df.columns.values.tolist() if "Junction" in x]
df2["Splicing Junction"]=df[cols].sum(axis=1)
try:
    df2=df2[['mRNA_CDS_exons','mRNA_UTR_exons','ncRNA_exons','UTR3','UTR5',"mRNA_Introns","Splicing Junction"]]
except:
    df2=df2[['mRNA_UTR_exons','ncRNA_exons',"3'-UTR","5'-UTR","mRNA_Introns","ncRNA_Introns","Splicing Junction"]]
df2
# Out:
#                      mRNA_UTR_exons ncRNA_exons    3'-UTR    5'-UTR mRNA_Introns ncRNA_Introns  Splicing Junction
# MiSeqSFPQc.csv Count       2.973241    16.74926  9.712587  9.712587       32.111      9.018831          19.722498
# MiSeqNONOc.csv Count       4.513889    17.36111  11.11111  9.722222     30.90278      11.34259          15.046296
#
# [2 rows x 7 columns]

# %%
import vincent 
vincent.core.initialize_notebook()
stack = vincent.StackedBar(df2)
stack.legend(title="Feature Type")
stack.colors(brew='Set3')
stack.axis_titles(x="Sample",y="Proportions of Bound Features, by %")
stack.display()
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# <div id="vis1139140c7603487aa2f0aee8da4dac1b"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [{"scale": "x", "title": "Sample", "type": "x"}, {"scale": "y", "title": "Proportions of Bound Features, by %", "type": "y"}], "data": [{"name": "table", "values": [{"col": "mRNA_UTR_exons", "idx": "MiSeqSFPQc.csv Count", "val": 2.9732408325074333}, {"col": "ncRNA_exons", "idx": "MiSeqSFPQc.csv Count", "val": 16.74925668979187}, {"col": "3'-UTR", "idx": "MiSeqSFPQc.csv Count", "val": 9.712586719524282}, {"col": "5'-UTR", "idx": "MiSeqSFPQc.csv Count", "val": 9.712586719524282}, {"col": "mRNA_Introns", "idx": "MiSeqSFPQc.csv Count", "val": 32.111000991080275}, {"col": "ncRNA_Introns", "idx": "MiSeqSFPQc.csv Count", "val": 9.018830525272548}, {"col": "Splicing Junction", "idx": "MiSeqSFPQc.csv Count", "val": 19.722497522299303}, {"col": "mRNA_UTR_exons", "idx": "MiSeqNONOc.csv Count", "val": 4.513888888888888}, {"col": "ncRNA_exons", "idx": "MiSeqNONOc.csv Count", "val": 17.36111111111111}, {"col": "3'-UTR", "idx": "MiSeqNONOc.csv Count", "val": 11.11111111111111}, {"col": "5'-UTR", "idx": "MiSeqNONOc.csv Count", "val": 9.722222222222223}, {"col": "mRNA_Introns", "idx": "MiSeqNONOc.csv Count", "val": 30.90277777777778}, {"col": "ncRNA_Introns", "idx": "MiSeqNONOc.csv Count", "val": 11.342592592592593}, {"col": "Splicing Junction", "idx": "MiSeqNONOc.csv Count", "val": 15.046296296296294}]}, {"name": "stats", "source": "table", "transform": [{"keys": ["data.idx"], "type": "facet"}, {"type": "stats", "value": "data.val"}]}], "height": 500, "legends": [{"fill": "color", "offset": 0, "properties": {}, "title": "Feature Type"}], "marks": [{"from": {"data": "table", "transform": [{"keys": ["data.col"], "type": "facet"}, {"height": "data.val", "point": "data.idx", "type": "stack"}]}, "marks": [{"properties": {"enter": {"fill": {"field": "data.col", "scale": "color"}, "width": {"band": true, "offset": -1, "scale": "x"}, "x": {"field": "data.idx", "scale": "x"}, "y": {"field": "y", "scale": "y"}, "y2": {"field": "y2", "scale": "y"}}}, "type": "rect"}], "type": "group"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "x", "range": "width", "type": "ordinal", "zero": false}, {"domain": {"data": "stats", "field": "sum"}, "name": "y", "nice": true, "range": "height"}, {"domain": {"data": "table", "field": "data.col"}, "name": "color", "range": ["#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f"], "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis1139140c7603487aa2f0aee8da4dac1b"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
